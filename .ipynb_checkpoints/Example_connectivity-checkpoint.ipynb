# %% [markdown]
# # Example Functional connectivity in Python
# ####  this code:
# ####  1) Imports the preprocessed and epoched python EEG data
# ####  2) Calculates the wPLI
#
# # ADD INFORMATION HERE

# %%
import matplotlib
import mne
import sys
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sys.path.append("../src")
import BIAPT_Connectivity

# Ensure Matplotlib uses the Qt5Agg backend, 
# which is the best choice for MNE-Python's 
# interactive plotting functions.
# matplotlib.use('Qt5Agg')

# %% [markdown]
# ### Which subject do you want to preprocess?

# %%
ID = "test"
task = "Base"

# %%
path_epochs = "../testdata/sub-{}/eeg/epochs_{}_{}.fif".format(ID,ID,task)
path_epochs
# Out:
# '../testdata/sub-test/eeg/epochs_test_Base.fif'

# %% [markdown]
# ## Load the preprocessed and epoched data

# %%
epochs = mne.read_epochs(path_epochs)
epochs = epochs.drop_channels(epochs.info['bads'])
# Out:
# Reading ../testdata/sub-test/eeg/epochs_test_Base.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9996.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 29 matching events found
# No baseline correction applied
# 0 projection items activated
# C:\Users\aboud\AppData\Local\Temp/ipykernel_30024/3477054251.py:1: RuntimeWarning: This filename (../testdata/sub-test/eeg/epochs_test_Base.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path_epochs)

# %% [markdown]
# #### The data is cropped in 10 s windows. There are 29 windos.
# ### Here, you get more information about the data

# %%
sfreq = int(epochs.info['sfreq'])

# %%
# define parameters: 
l_freq = 7
h_freq = 13
window_length = 10
step_size = 10

# %% [markdown]
# ## calculate the wPLI

# %%
# filter the epochs
epochs_filtered = epochs.filter(l_freq, h_freq)
# Out:
# Setting up band-pass filter from 7 - 13 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 13.00 Hz
# - Upper transition bandwidth: 3.25 Hz (-6 dB cutoff frequency: 14.62 Hz)
# - Filter length: 413 samples (1.652 sec)

# %%
#concatinate back the windows
raw_data = epochs_filtered.get_data()
print(raw_data.shape)
raw_data = raw_data.reshape(raw_data.shape[1], raw_data.shape[0]*raw_data.shape[2])
print(raw_data.shape)
# Out:
# (29, 105, 2500)
# (105, 72500)

# %%
# Calculating wpLI in a time-resolved way (no surrogates)
wpli = BIAPT_Connectivity.connectivity_compute(raw_data, window_length,step_size, l_freq, h_freq, sfreq, n_surrogates=0, mode="wpli", verbose=False)
# Calculating wpLI in a time-resolved way (with surrogates)
wpli_surrogates_20 = BIAPT_Connectivity.connectivity_compute(raw_data, window_length,step_size, l_freq, h_freq, sfreq, n_surrogates=20, mode="wpli", verbose=False)

wpli_surrogates_50 = BIAPT_Connectivity.connectivity_compute(raw_data, window_length,step_size, l_freq, h_freq, sfreq, n_surrogates=50, mode="wpli", verbose=False)
# Out:
# C:\Users\aboud\miniconda3\envs\bien470\lib\site-packages\scipy\stats\morestats.py:3141: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "

# %%
average_wpli = np.mean(wpli, axis=0)
average_wpli_surrogates_20= np.mean(wpli_surrogates_20, axis=0)
average_wpli_surrogates_50= np.mean(wpli_surrogates_50, axis=0)
# data visualization
fig, axs = plt.subplots(1, 3, figsize=(25, 5))
for ax in axs:
    ax.set_axis_off()
sns.heatmap(average_wpli, cmap='YlGnBu', ax=axs[0], vmin=-1, vmax=1)
axs[0].set_title("WPLI-No Surrogates")
sns.heatmap(average_wpli_surrogates_20, cmap='YlGnBu', ax=axs[1], vmin=-1, vmax=1)
axs[1].set_title("WPLI with 20 Surrogates")
sns.heatmap(average_wpli_surrogates_50, cmap='YlGnBu', ax=axs[2], vmin=-1, vmax=1)
axs[2].set_title("WPLI with 50 Surrogates")
# Out:
# Text(0.5, 1.0, 'WPLI with 50 Surrogates')

# %%
# Calculating dpLI in a time-resolved way (no surrogates)
dpli = BIAPT_Connectivity.connectivity_compute(raw_data, window_length,step_size, l_freq, h_freq, sfreq, n_surrogates=0, mode="dpli", verbose=False)
# Calculating dpLI in a time-resolved way (with surrogates)
dpli_surrogates_20 = BIAPT_Connectivity.connectivity_compute(raw_data, window_length,step_size, l_freq, h_freq, sfreq, n_surrogates=20, mode="dpli", verbose=False)

dpli_surrogates_50 = BIAPT_Connectivity.connectivity_compute(raw_data, window_length,step_size, l_freq, h_freq, sfreq, n_surrogates=50, mode="dpli", verbose=False)
# Out:
# C:\Users\aboud\miniconda3\envs\bien470\lib\site-packages\scipy\stats\morestats.py:3141: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "

# %%
average_dpli = np.mean(dpli, axis=0)
average_dpli_surrogates_20= np.mean(dpli_surrogates_20, axis=0)
average_dpli_surrogates_50= np.mean(dpli_surrogates_50, axis=0)
# data visualization
fig, axs = plt.subplots(1, 3, figsize=(25, 5))
for ax in axs:
    ax.set_axis_off()
sns.heatmap(average_dpli, cmap='YlGnBu', ax=axs[0], vmin=-1, vmax=1)
axs[0].set_title("dPLI-No Surrogates")
sns.heatmap(average_dpli_surrogates_20, cmap='YlGnBu', ax=axs[1], vmin=-1, vmax=1)
axs[1].set_title("dPLI with 20 Surrogates")
sns.heatmap(average_dpli_surrogates_50, cmap='YlGnBu', ax=axs[2], vmin=-1, vmax=1)
axs[2].set_title("dPLI with 50 Surrogates")
# Out:
# Text(0.5, 1.0, 'dPLI with 50 Surrogates')

# %%
aec = BIAPT_Connectivity.connectivity_compute(raw_data, window_length,step_size, l_freq, h_freq, sfreq, n_surrogates=0, mode="aec", verbose=False)
average_aec = np.mean(aec, axis=0)
plt.figure()
ax = sns.heatmap(average_aec, cmap='YlGnBu',ax=None, vmin=-1, vmax=1)
ax.set_xticks([])
ax.set_yticks([])
plt.title("AEC")
plt.show()
